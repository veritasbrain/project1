# %% [markdown]
# <a href="https://colab.research.google.com/github/veritasbrain/project1/blob/main/VB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Added

# %%
print("Veritas")
# Out:
# Veritas

# %%
# !pip3 install ColabTurtle

# %%
import ColabTurtle.Turtle as alex
alex.initializeTurtle(initial_speed= 2)
alex.color('brown')
alex.forward(150)
alex.left(90)
alex.forward(75)
alex.up()
alex.forward(30)
alex.down()
alex.forward(30)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="100.0" stroke-linecap="round" style="stroke:brown;stroke-width:4"/><line x1="400.0" y1="100.0" x2="325.0" y2="100.0" stroke-linecap="round" style="stroke:brown;stroke-width:4"/><line x1="295.0" y1="100.0" x2="265.0" y2="100.0" stroke-linecap="round" style="stroke:brown;stroke-width:4"/>
#         <g visibility=visible transform="rotate(270,265.0,100.0) translate(247.0, 82.0)">
# ...

# %%
import ColabTurtle.Turtle as alex
alex.initializeTurtle(6)
alex.color("blue")

# draw 4-side
alex.forward(100)
alex.right(90)
alex.forward(100)
alex.right(90)
alex.forward(100)
alex.right(90)
alex.forward(100)
alex.right(90)

# moving
alex.up()
alex.forward(50)
alex.down()

# draw 3-side
alex.forward(100)
alex.right(120)
alex.forward(100)
alex.right(120)
alex.forward(100)
alex.right(120)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#         <line x1="400" y1="250" x2="400.0" y2="150.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="400.0" y1="150.0" x2="500.0" y2="150.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="500.0" y1="150.0" x2="500.0" y2="250.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="500.0" y1="250.0" x2="400.0" y2="250.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="400.0" y1="200.0" x2="400.0" y2="100.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="400.0" y1="100.0" x2="486.603" y2="150.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/><line x1="486.603" y1="150.0" x2="400.0" y2="200.0" stroke-linecap="round" style="stroke:blue;stroke-width:4"/>
#         <g visibility=visible transform="rotate(360,400.0,200.0) translate(382.0, 182.0)">
# ...

# %%
alex.fillcolor?
# Out:
# Object `alex.fillcolor` not found.

# %%
import ColabTurtle.Turtle as alex
alex.initializeTurtle(13)

sides=int(input("Insert sides"))
l = int(input("insert length "))
color = input("insert line color")
fill_color = input("insert fill color")
alex.color(color)
fillcolor(fill_color)


ang = 360/sides
begin_fill()
for i in range(sides):
  alex.forward(l)
  alex.left(ang)
end_fill()
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
#
#         <g visibility=visible transform="rotate(360,400,250) translate(382, 232)">
# ...

# %%
fill
# Out:
# <module 'ColabTurtle.Turtle' from '/usr/local/lib/python3.11/dist-packages/ColabTurtle/Turtle.py'>

# %%
import ColabTurtle.Turtle as alex
alex.initializeTurtle(8)

side_len= int(input("enter side length"))

for p in range(4):
  for o in range(4):
    alex.forward(side_len)
    alex.right(90)
  alex.left(90)


for u in range(4):
  for y in range(4):
    alex.forward(2*side_len)
    alex.right(90)
  alex.left(90)
# Out:
#       <svg width="800" height="500">
#         <rect width="100%" height="100%" fill="black"/>
# ...

# %% [markdown]
# # Header
# ## sub header
